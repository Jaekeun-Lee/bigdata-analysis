# %%
# P12 - In-class Linear Regress Example
# 스파크의 MLlib을 잘 활용하려면 데이터의 양, feature 추출, 머신러닝 알고리즘 구현, 평가 이 4가지 단계의 파이프 라인이 잘 구성되어야 한다고 느꼈습니다. 그 중 원인 요소들 (feature)을 잘 찾아 결과에 적용될 수 있도록 함수에 공급할 특성(feature)을 찾는 과정 즉, 특성추출이 가장 중요한 단계 같다고 느꼈습니다.

# %%
import findspark

# %%
findspark.init('C:\spark-2.4.5-bin-hadoop2.7')

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('lr_example').getOrCreate()

# %%
from pyspark.ml.regression import LinearRegression

# %%
training = spark.read.format('libsvm').load('sample_linear_regression_data.txt')

# %%
training.show()
# Out:
# +-------------------+--------------------+
# |              label|            features|
# +-------------------+--------------------+
# | -9.490009878824548|(10,[0,1,2,3,4,5,...|
# | 0.2577820163584905|(10,[0,1,2,3,4,5,...|
# | -4.438869807456516|(10,[0,1,2,3,4,5,...|
# |-19.782762789614537|(10,[0,1,2,3,4,5,...|
# | -7.966593841555266|(10,[0,1,2,3,4,5,...|
# | -7.896274316726144|(10,[0,1,2,3,4,5,...|
# | -8.464803554195287|(10,[0,1,2,3,4,5,...|
# | 2.1214592666251364|(10,[0,1,2,3,4,5,...|
# | 1.0720117616524107|(10,[0,1,2,3,4,5,...|
# |-13.772441561702871|(10,[0,1,2,3,4,5,...|
# | -5.082010756207233|(10,[0,1,2,3,4,5,...|
# |  7.887786536531237|(10,[0,1,2,3,4,5,...|
# | 14.323146365332388|(10,[0,1,2,3,4,5,...|
# |-20.057482615789212|(10,[0,1,2,3,4,5,...|
# |-0.8995693247765151|(10,[0,1,2,3,4,5,...|
# | -19.16829262296376|(10,[0,1,2,3,4,5,...|
# |  5.601801561245534|(10,[0,1,2,3,4,5,...|
# |-3.2256352187273354|(10,[0,1,2,3,4,5,...|
# | 1.5299675726687754|(10,[0,1,2,3,4,5,...|
# | -0.250102447941961|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows

# %%
lr = LinearRegression(featuresCol='features', labelCol='label', predictionCol='prediction')

# %%
lrModel = lr.fit(training)

# %%
lrModel.coefficients
# Out:
# DenseVector([0.0073, 0.8314, -0.8095, 2.4412, 0.5192, 1.1535, -0.2989, -0.5129, -0.6197, 0.6956])

# %%
lrModel.intercept
# Out:
# 0.14228558260358093

# %%
trainingSummary = lrModel.summary

# %%
trainingSummary.residuals.show()
# Out:
# +-------------------+
# |          residuals|
# +-------------------+
# |-11.011130022096554|
# | 0.9236590911176538|
# |-4.5957401897776675|
# |  -20.4201774575836|
# |-10.339160314788181|
# |-5.9552091439610555|
# |-10.726906349283922|
# |  2.122807193191233|
# |  4.077122222293811|
# |-17.316168071241652|
# | -4.593044343959059|
# |  6.380476690746936|
# | 11.320566035059846|
# |-20.721971774534094|
# | -2.736692773777401|
# | -16.66886934252847|
# |  8.242186378876315|
# |-1.3723486332690233|
# |-0.7060332131264666|
# |-1.1591135969994064|
# +-------------------+
# only showing top 20 rows

# %%
trainingSummary.rootMeanSquaredError
# Out:
# 10.16309157133015

# %%
trainingSummary.r2
# Out:
# 0.027839179518600154

# %%
all_data = spark.read.format('libsvm').load('sample_linear_regression_data.txt')

# %%
train_data,test_data = all_data.randomSplit([0.7,0.3])

# %%
train_data.show()
# Out:
# +-------------------+--------------------+
# |              label|            features|
# +-------------------+--------------------+
# |-28.046018037776633|(10,[0,1,2,3,4,5,...|
# |-26.805483428483072|(10,[0,1,2,3,4,5,...|
# | -23.51088409032297|(10,[0,1,2,3,4,5,...|
# |-23.487440120936512|(10,[0,1,2,3,4,5,...|
# |-22.949825936196074|(10,[0,1,2,3,4,5,...|
# |-21.432387764165806|(10,[0,1,2,3,4,5,...|
# |-20.212077258958672|(10,[0,1,2,3,4,5,...|
# |-20.057482615789212|(10,[0,1,2,3,4,5,...|
# |-19.872991038068406|(10,[0,1,2,3,4,5,...|
# |-19.782762789614537|(10,[0,1,2,3,4,5,...|
# | -19.66731861537172|(10,[0,1,2,3,4,5,...|
# |-19.402336030214553|(10,[0,1,2,3,4,5,...|
# |-18.845922472898582|(10,[0,1,2,3,4,5,...|
# | -18.27521356600463|(10,[0,1,2,3,4,5,...|
# |-17.428674570939506|(10,[0,1,2,3,4,5,...|
# | -17.32672073267595|(10,[0,1,2,3,4,5,...|
# |-17.065399625876015|(10,[0,1,2,3,4,5,...|
# | -16.71909683360509|(10,[0,1,2,3,4,5,...|
# |-16.692207021311106|(10,[0,1,2,3,4,5,...|
# |-16.151349351277112|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows

# %%
test_data.show()
# Out:
# +-------------------+--------------------+
# |              label|            features|
# +-------------------+--------------------+
# |-28.571478869743427|(10,[0,1,2,3,4,5,...|
# |-26.736207182601724|(10,[0,1,2,3,4,5,...|
# |-22.837460416919342|(10,[0,1,2,3,4,5,...|
# |-19.884560774273424|(10,[0,1,2,3,4,5,...|
# | -19.16829262296376|(10,[0,1,2,3,4,5,...|
# |-17.803626188664516|(10,[0,1,2,3,4,5,...|
# |-17.494200356883344|(10,[0,1,2,3,4,5,...|
# |-17.026492264209548|(10,[0,1,2,3,4,5,...|
# | -16.26143027545273|(10,[0,1,2,3,4,5,...|
# |-15.780685032623301|(10,[0,1,2,3,4,5,...|
# |-15.375857723312297|(10,[0,1,2,3,4,5,...|
# |-15.348871155379253|(10,[0,1,2,3,4,5,...|
# |-15.334767479922341|(10,[0,1,2,3,4,5,...|
# |-14.762758252931127|(10,[0,1,2,3,4,5,...|
# | -12.92222310337042|(10,[0,1,2,3,4,5,...|
# |-12.094351278535258|(10,[0,1,2,3,4,5,...|
# |-11.328415936777782|(10,[0,1,2,3,4,5,...|
# | -10.57769830424322|(10,[0,1,2,3,4,5,...|
# |-10.288657252388708|(10,[0,1,2,3,4,5,...|
# |-10.233439586953153|(10,[0,1,2,3,4,5,...|
# +-------------------+--------------------+
# only showing top 20 rows

# %%
unlabeled_data = test_data.select('features')

# %%
unlabeled_data.show()
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# |(10,[0,1,2,3,4,5,...|
# +--------------------+
# only showing top 20 rows

# %%
correct_model = lr.fit(train_data)

# %%
test_result = correct_model.evaluate(test_data)

# %%
test_result.residuals.show()
# Out:
# +-------------------+
# |          residuals|
# +-------------------+
# | -28.51061271990803|
# | -25.00116057252445|
# | -21.22633406654368|
# |-20.859469978329564|
# |-19.052960617652303|
# |-14.769140257117591|
# |-16.505204083043388|
# |-14.026490058742231|
# |  -20.7698971296864|
# |-19.523863156990487|
# |-16.915383525856484|
# |-13.174393257579219|
# | -18.58222959192217|
# |-14.566014080031831|
# |-16.015726190534878|
# | -11.35254981472467|
# |-13.417350011466647|
# | -8.596680917173655|
# |-10.134434045023562|
# | -8.915615531399679|
# +-------------------+
# only showing top 20 rows

# %%
test_result.rootMeanSquaredError
# Out:
# 9.976165100005396

# %%
predictions = correct_model.transform(unlabeled_data)

# %%
predictions.show()
# Out:
# +--------------------+--------------------+
# |            features|          prediction|
# +--------------------+--------------------+
# |(10,[0,1,2,3,4,5,...|-0.06086614983539951|
# |(10,[0,1,2,3,4,5,...|  -1.735046610077274|
# |(10,[0,1,2,3,4,5,...| -1.6111263503756639|
# |(10,[0,1,2,3,4,5,...|  0.9749092040561385|
# |(10,[0,1,2,3,4,5,...|-0.11533200531145771|
# |(10,[0,1,2,3,4,5,...| -3.0344859315469255|
# |(10,[0,1,2,3,4,5,...| -0.9889962738399536|
# |(10,[0,1,2,3,4,5,...| -3.0000022054673163|
# |(10,[0,1,2,3,4,5,...|   4.508466854233667|
# |(10,[0,1,2,3,4,5,...|  3.7431781243671858|
# |(10,[0,1,2,3,4,5,...|  1.5395258025441867|
# |(10,[0,1,2,3,4,5,...|  -2.174477897800035|
# |(10,[0,1,2,3,4,5,...|  3.2474621119998317|
# |(10,[0,1,2,3,4,5,...|-0.19674417289929608|
# |(10,[0,1,2,3,4,5,...|   3.093503087164456|
# |(10,[0,1,2,3,4,5,...| -0.7418014638105881|
# |(10,[0,1,2,3,4,5,...|   2.088934074688865|
# |(10,[0,1,2,3,4,5,...| -1.9810173870695647|
# |(10,[0,1,2,3,4,5,...|-0.15422320736514578|
# |(10,[0,1,2,3,4,5,...| -1.3178240555534748|
# +--------------------+--------------------+
# only showing top 20 rows
